# %% [markdown]
# # Tokenization
#
# Chapter 03 exercises: a character tokenizer and one BPE merge.
#
# This is the full **PyTorch** version of a challenge from [LLM Quest](https://bankoti.github.io/llm-quest). The in-browser challenge grades numpy; here you work with real tensors. Fill in each `TODO`, then run the checks cell.
#
# Runs on the free Colab CPU runtime; switch to a GPU via *Runtime > Change runtime type* if you want to experiment at scale. PyTorch comes preinstalled.

# %%
from typing import Dict, List, Sequence, Tuple


def build_vocabulary(text: str) -> Tuple[Dict[str, int], Dict[int, str]]:
    """Return character-to-id and id-to-character dictionaries."""
    raise NotImplementedError


def encode(text: str, stoi: Dict[str, int]) -> List[int]:
    raise NotImplementedError


def decode(ids: Sequence[int], itos: Dict[int, str]) -> str:
    raise NotImplementedError


def merge_pair(
    ids: Sequence[int], pair: Tuple[int, int], replacement: int
) -> List[int]:
    """Replace non-overlapping adjacent occurrences of pair from left to right."""
    raise NotImplementedError


sample = "tokens become numbers; numbers become vectors."
stoi, itos = build_vocabulary(sample)

# %%
assert decode(encode(sample, stoi), itos) == sample
assert merge_pair([1, 2, 1, 2, 2], (1, 2), 9) == [9, 9, 2]
print("Tokenizer checks passed.")
