# %% [markdown]
# # The Transformer
#
# Chapter 08 capstone scaffold: assemble a tiny decoder-only Transformer.
#
# Implement these pieces in order. Keep shape comments on every forward method.
# Compare behavior, not line-for-line code, with src/mini_llm/models.py.
#
# This is the full **PyTorch** version of a challenge from [LLM Quest](https://bankoti.github.io/llm-quest). The in-browser challenge grades numpy; here you work with real tensors. Fill in each `TODO`, then run the checks cell.
#
# Runs on the free Colab CPU runtime; switch to a GPU via *Runtime > Change runtime type* if you want to experiment at scale. PyTorch comes preinstalled.

# %%
from typing import Optional, Tuple

import torch
import torch.nn as nn


class CausalSelfAttention(nn.Module):
    """TODO: QKV projection, heads, scaled scores, mask, softmax, output projection."""

    def __init__(self, width: int, heads: int, block_size: int) -> None:
        super().__init__()
        raise NotImplementedError

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        raise NotImplementedError


class FeedForward(nn.Module):
    """TODO: width -> 4*width -> GELU -> width."""

    def __init__(self, width: int) -> None:
        super().__init__()
        raise NotImplementedError

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        raise NotImplementedError


class TransformerBlock(nn.Module):
    """TODO: two pre-norm residual updates."""

    def __init__(self, width: int, heads: int, block_size: int) -> None:
        super().__init__()
        raise NotImplementedError

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        raise NotImplementedError


class TinyGPT(nn.Module):
    """TODO: embeddings, blocks, final norm, LM head, and cross-entropy."""

    def __init__(
        self, vocab_size: int, block_size: int, width: int, heads: int, layers: int
    ) -> None:
        super().__init__()
        raise NotImplementedError

    def forward(
        self, inputs: torch.Tensor, targets: Optional[torch.Tensor] = None
    ) -> Tuple[torch.Tensor, Optional[torch.Tensor]]:
        raise NotImplementedError


model = TinyGPT(vocab_size=17, block_size=8, width=32, heads=4, layers=2)
x = torch.randint(0, 17, (2, 8))
logits, loss = model(x, x)

# %%
assert logits.shape == (2, 8, 17)
assert loss is not None and loss.ndim == 0
print("Transformer checks passed.")
